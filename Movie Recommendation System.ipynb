# %%
#Importing required python packages
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer as CntVect
from sklearn.metrics.pairwise import cosine_similarity as CosSim

# %%
# Read CSV file
movies=pd.read_csv('C:/Users/amrut/Downloads/netflix_titles.csv')

# %%
movies.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
# Data preprocessing
movies=movies.dropna().reset_index(drop=True)
movies=movies.rename(columns={'listed_in':'genre'})
movies.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80125979  Movie                             #realityhigh
# 2  70304989  Movie                                 Automata
# 3  80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 4  70304990  Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                 Fernando Lebrija
# 2                      Gabe Ibáñez
# 3  Rodrigo Toro, Francisco Schultz
# 4                Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 2  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 3                                    Fabrizio Copano
# 4  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
# ...

# %%
# Feature Selection and Combining them
features=movies[['director','cast','genre']]
features_combined=features['director']+" "+features['cast']+" "+features['genre']

# %%
features_combined.head()
# Out:
# 0    Richard Finn, Tim Maltby Alan Marriott, Andrew...
# 1    Fernando Lebrija Nesta Cooper, Kate Walsh, Joh...
# 2    Gabe Ibáñez Antonio Banderas, Dylan McDermott,...
# 3    Rodrigo Toro, Francisco Schultz Fabrizio Copan...
# 4    Henrik Ruben Genz James Franco, Kate Hudson, T...
# dtype: object

# %%
# Count matrix
matrix_count=CntVect().fit_transform(features_combined)
matrix_count=matrix_count.toarray()

# %%
# Cosine Similarity
similarity=CosSim(matrix_count)
similarity
# Out:
# array([[1.        , 0.06900656, 0.07027284, ..., 0.        , 0.05015699,
#         0.03001501],
#        [0.06900656, 1.        , 0.        , ..., 0.        , 0.        ,
#         0.03106849],
#        [0.07027284, 0.        , 1.        , ..., 0.03456506, 0.02643505,
#         0.0316386 ],
#        ...,
#        [0.        , 0.        , 0.03456506, ..., 1.        , 0.32071891,
#         0.44290395],
#        [0.05015699, 0.        , 0.02643505, ..., 0.32071891, 1.        ,
#         0.29356519],
#        [0.03001501, 0.03106849, 0.0316386 , ..., 0.44290395, 0.29356519,
#         1.        ]])

# %%
movies.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80125979  Movie                             #realityhigh
# 2  70304989  Movie                                 Automata
# 3  80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 4  70304990  Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                 Fernando Lebrija
# 2                      Gabe Ibáñez
# 3  Rodrigo Toro, Francisco Schultz
# 4                Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 2  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 3                                    Fabrizio Copano
# 4  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
# ...

# %%
#Finding index of movie watched by the user
User_pref="Good People"
movie_index=movies.index[movies['title']==User_pref].values[0]
#movie_index=movies.iloc[movie_index]
movie_index
# Out:
# 4

# %%
#Recommending movies based on movie watched by the user
recommendations=list(enumerate(similarity[movie_index]))
recommendations
# Out:
# [(0, 0.034503277967117704),
#  (1, 0.07142857142857141),
#  (2, 0.036369648372665396),
#  (3, 0.0),
#  (4, 0.9999999999999997),
#  (5, 0.1543033499620919),
#  (6, 0.0),
#  (7, 0.07559289460184544),
#  (8, 0.11338934190276817),
#  (9, 0.10714285714285712),
#  (10, 0.0),
#  (11, 0.0),
#  (12, 0.0),
#  (13, 0.03940552031195503),
#  (14, 0.0),
#  (15, 0.07018624063435963),
#  (16, 0.0),
#  (17, 0.03706246583305506),
#  (18, 0.0),
#  (19, 0.10714285714285712),
#  (20, 0.0),
#  (21, 0.036369648372665396),
#  (22, 0.0),
#  (23, 0.0),
#  (24, 0.0),
#  (25, 0.0),
#  (26, 0.0),
#  (27, 0.0),
#  (28, 0.0),
#  (29, 0.0),
#  (30, 0.0),
#  (31, 0.0),
#  (32, 0.0),
#  (33, 0.0),
#  (34, 0.0),
#  (35, 0.0),
#  (36, 0.0885422004151433),
#  (37, 0.0),
#  (38, 0.0),
#  (39, 0.036369648372665396),
#  (40, 0.0),
#  (41, 0.1336306209562122),
#  (42, 0.06900655593423541),
#  (43, 0.0),
#  (44, 0.0975900072948533),
#  (45, 0.0),
#  (46, 0.0),
#  (47, 0.03857583749052298),
#  (48, 0.0),
# ...

# %%
#Sorting in descending order to find movies most related
recommendations=sorted(recommendations,key=lambda x:x[1], reverse=True)
recommendations
# Out:
# [(4, 0.9999999999999997),
#  (926, 0.21459876881973805),
#  (736, 0.20145574100634503),
#  (653, 0.1928791874526149),
#  (2389, 0.19166296949998193),
#  (934, 0.18641092980036),
#  (68, 0.1853123291652753),
#  (493, 0.1853123291652753),
#  (1204, 0.18394180184548975),
#  (2651, 0.181848241863327),
#  (2926, 0.181848241863327),
#  (2484, 0.17928429140015906),
#  (517, 0.17857142857142852),
#  (1781, 0.1781741612749496),
#  (727, 0.1770844008302866),
#  (738, 0.17546560158589908),
#  (330, 0.17251638983558854),
#  (1136, 0.16971105832553265),
#  (1538, 0.1653953539259914),
#  (933, 0.1649572197684645),
#  (2962, 0.1649572197684645),
#  (775, 0.16448792373994225),
#  (2342, 0.15762208124782012),
#  (654, 0.1553424415003),
#  (3033, 0.1553424415003),
#  (3466, 0.1553424415003),
#  (5, 0.1543033499620919),
#  (150, 0.1543033499620919),
#  (3406, 0.1543033499620919),
#  (1351, 0.15118578920369088),
#  (2006, 0.15118578920369088),
#  (1716, 0.1494035761667992),
# ...

# %%
#Printing recommended movies
i=0
for movie in recommendations:
    print(movies['title'].iloc[movie[0]])
    i=i+1
    if(i>10):
        break
# Out:
# Good People
# Spider-Man 3
# Mercy
# Outlaw King
# Inception
# The Great Raid
# USS Indianapolis: Men of Courage
# Exit Wounds
# Robin Hood: The Rebellion
# All Light Will End
# War on Everyone
